# %% [markdown]
# <a href="https://colab.research.google.com/github/sj-onu/Python_own/blob/master/matploylib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

# %%
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])

# %%
import numpy as np

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
plt.scatter(x, y)

# %%
line, = plt.plot(x, y, '-')
line.set_antialiased(False)

# %%
lines = plt.plot([1, 2, 3])

# %%
plt.plot(x,y, color='red',linewidth=2)

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')

# %%
x=[12,8,10]
y=[12,16,6]
x1=[6,9,11]
y2=[6,15,7]

# %%
plt.plot(x,y,'g',label='line one',linewidth=5)
plt.plot(x1,y2,'b',label='line two',linewidth=5)

# %%
plt.bar(x,y)
#plt.bar(x1,y2)
# Out:
# <BarContainer object of 3 artists>

# %%
plt.plot(x, y, 'bo')

# %%
plt.plot(x)

# %%
plt.plot(y)

# %%
plt.plot(y, 'r+')

# %%
plt.plot(x,y, color='red',linewidth=5,linestyle='dotted')

# %%
plt.xlabel('Day')
plt.ylabel('time')
plt.title('Chart')
plt.plot(x,y, color='red',linewidth=5,linestyle='dotted')

# %%
plt.plot(x,y,color='blue',marker='+',linestyle='dotted',markersize=20)

# %%
plt.plot(x,y,alpha=90)

# %%
import matplotlib.pyplot as plt


labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]
width = 0.65       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, men_means, width, yerr=men_std, label='Men')
ax.bar(labels, women_means, width, yerr=women_std, bottom=men_means,
       label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

plt.show()

# %%
import seaborn as sns

# %%
sns.get_dataset_names
# Out:
# <function seaborn.utils.get_dataset_names>

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as pd
import numpy as np
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-03d3d489-4f86-4eb7-b096-afa74b085171" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-03d3d489-4f86-4eb7-b096-afa74b085171">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Weather.csv to Weather (1).csv

# %%
import io

# %%
df=pd.read_csv(io.BytesIO(uploaded['Weather.csv']))

# %%
df.head()
# Out:
#        Date  Temperature  Humidity  WindSpeed Events
# 0  1/1/2020         38.0      52.0        8.0    NAN
# 1  1/2/2020         36.0      46.0        7.0    NAN
# 2  1/3/2020         40.0      47.0        8.0   Rain
# 3  1/4/2020         25.0      44.0        NaN   Rain
# 4  1/5/2020         22.0      35.0        6.0    NAN

# %%
df.Temperature.max()
# Out:
# 50.0

# %%
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('Chart')
labels = ['Temperature','Humidity','WindSpeed']
plt.plot(df.Temperature,'g',linewidth=1)
plt.plot(df.Humidity,'b',label='line two',linewidth=1)
plt.plot(df.WindSpeed,'r',label='line three',linewidth=1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import pandas as pd
import numpy as np

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='day',y='total_bill',estimator = np.median, data=df)

# %% [markdown]
# Capsize

# %%
sns.barplot(x='day',y='total_bill',ci = 60,capsize= 0.3,data=df)

# %% [markdown]
# Barplots of same colour

# %%
sns.barplot(x='day',y='total_bill',color='blue',data=df)

# %% [markdown]
# Saturation Level

# %%
sns.barplot(x='day',y='total_bill',color='green',saturation=0.5,data=df)

# %% [markdown]
# Saving plots is file

# %%
sns_plot=sns.barplot(x='day',y='total_bill', data=df)

# %%
fig=sns_plot.get_figure()

# %%
fig.savefig(fname='plot.png')
